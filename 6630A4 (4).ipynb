# %%
import pandas as pd

# # of construction tpye/total # of homes
prior_probs = {"Apartment": 7 / 20, "House": 7 / 20, "Condo": 6 / 20}

#\ using equal length binning. Bin Width = #bins / max val- min val

conditional_probs = {
     "Local Price": { # P(Local Price | Construction type) = (#Rows with Local Price in range AND Construction type) / (Total # Rows for Construction type)
        "[3.891, 5.144)": {"Apartment": 0.5714, "House": 0.1429, "Condo": 0.3333},
        "[5.144, 6.397)": {"Apartment": 0.0, "House": 0.7143, "Condo": 0.3333},
        "[15.167, 16.433)": {"Apartment": 0.0, "House": 0.0, "Condo": 0.1667},
        "[13.914, 15.167)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
        "[7.65, 8.903)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.1667},
        "[6.397, 7.65)": {"Apartment": 0.0, "House": 0.1429, "Condo": 0.0},
        "[8.903, 10.156)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
    },
    "Land Area": { # P(Land Area | Construction type) = (#Rows with Land Area in range AND Construction type) / (Total # Rows for Construction type)
        "[3.327, 4.38)": {"Apartment": 0.2857, "House": 0.1429, "Condo": 0.0},
        "[2.275, 3.327)": {"Apartment": 0.0, "House": 0.0, "Condo": 0.1667},
        "[4.38, 5.432)": {"Apartment": 0.4286, "House": 0.1429, "Condo": 0.1667},
        "[5.432, 6.485)": {"Apartment": 0.0, "House": 0.2857, "Condo": 0.1667},
        "[8.59, 9.642)": {"Apartment": 0.0, "House": 0.2857, "Condo": 0.0},
        "[9.642, 10.695)": {"Apartment": 0.0, "House": 0.0, "Condo": 0.1667},
        "[11.748, 12.811)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
        "[6.485, 7.538)": {"Apartment": 0.0, "House": 0.1429, "Condo": 0.3333},
        "[7.538, 8.59)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
    },
    "Living area": { # P(Living area | Construction type) = (#Rows with Living area in range AND Construction type) / (Total # Rows for Construction type)
        "[0.975, 1.22)": {"Apartment": 0.4286, "House": 0.1429, "Condo": 0.5},
        "[1.464, 1.708)": {"Apartment": 0.2857, "House": 0.7143, "Condo": 0.0},
        "[1.22, 1.464)": {"Apartment": 0.1429, "House": 0.1429, "Condo": 0.3333},
        "[3.176, 3.422)": {"Apartment": 0.0, "House": 0.0, "Condo": 0.1667},
        "[2.931, 3.176)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},


    }, "# Garages": {
        1.0: {"Apartment": 0.4286, "House": 0.2857, "Condo": 0.6667},
        2.0: {"Apartment": 0.2857, "House": 0.2857, "Condo": 0.3333},
        0.0: {"Apartment": 0.1429, "House": 0.2857, "Condo": 0.0},
        1.5: {"Apartment": 0.1429, "House": 0.1429, "Condo": 0.0},
    },
    "# Rooms": {
        7.0: {"Apartment": 0.2857, "House": 0.2857, "Condo": 0.1667},
        6.0: {"Apartment": 0.2857, "House": 0.5714, "Condo": 0.6667},
        10.0: {"Apartment": 0.0, "House": 0.0, "Condo": 0.1667},
        9.0: {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
        5.0: {"Apartment": 0.1429, "House": 0.1429, "Condo": 0.0},
        8.0: {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
    },
    "# Bedrooms": {
        4.0: {"Apartment": 0.2857, "House": 0.1429, "Condo": 0.0},
        3.0: {"Apartment": 0.4286, "House": 0.7143, "Condo": 0.8333},
        5.0: {"Apartment": 0.1429, "House": 0.0, "Condo": 0.1667},
        2.0: {"Apartment": 0.1429, "House": 0.1429, "Condo": 0.0},
    },
    "Age of home": { # P(Age of home | Construction type) = (#Rows with Age in range AND Construction type) / (Total # Rows for Construction type)
        "[38.0, 42.8)": {"Apartment": 0.2857, "House": 0.0, "Condo": 0.3333},
        "[57.2, 62.048)": {"Apartment": 0.0, "House": 0.1429, "Condo": 0.0},
        "[52.4, 57.2)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.1667},
        "[47.6, 52.4)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.1667},
        "[28.4, 33.2)": {"Apartment": 0.0, "House": 0.7143, "Condo": 0.1667},
        "[14.0, 18.8)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.1667},
        "[42.8, 47.6)": {"Apartment": 0.1429, "House": 0.0, "Condo": 0.0},
        "[18.8, 23.6)": {"Apartment": 0.1429, "House": 0.1429, "Condo": 0.0},
    },

}


file_path = '/content/Asssignment4_Data.xlsx'
test_data = pd.read_excel(file_path, sheet_name='Test')

# Naïve Bayes
def classify(test_data, prior_probs, conditional_probs):
    predictions = []

    for _, test_row in test_data.iterrows():
        posteriors = {}
        for cls in prior_probs:
            # Start with the prior probability
            posterior = prior_probs[cls]
            for feature, value in test_row.items():
                # Multiply by the conditional probability
                if feature in conditional_probs and value in conditional_probs[feature]:
                    posterior *= conditional_probs[feature][value].get(cls, 1e-6)
            posteriors[cls] = posterior

        predicted_class = max(posteriors, key=posteriors.get)
        predictions.append((predicted_class, posteriors))

    return predictions

results = classify(test_data, prior_probs, conditional_probs)


for idx, (predicted_class, probabilities) in enumerate(results):
    print(f"Test Instance {idx + 1}:")
    for cls, prob in probabilities.items():
        print(f"  {cls}: {prob:.6f}")
    print(f"Predicted Class: {predicted_class}\n")
# Out:
# Test Instance 1:
#   Apartment: 0.018369
#   House: 0.040813
#   Condo: 0.111118
# Predicted Class: Condo
#
# Test Instance 2:
#   Apartment: 0.004082
#   House: 0.000000
#   Condo: 0.000000
# Predicted Class: Apartment
#
# Test Instance 3:
#   Apartment: 0.012244
#   House: 0.020407
#   Condo: 0.013890
# Predicted Class: House
#
# Test Instance 4:
#   Apartment: 0.002042
#   House: 0.000000
#   Condo: 0.000000
# Predicted Class: Apartment
#
# Test Instance 5:
#   Apartment: 0.012244
#   House: 0.040813
#   Condo: 0.055551
# Predicted Class: Condo

# %% [markdown]
# I used eqaul width binning for the scattered or continouse variables to keep it simple.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the data
file_path = '/content/Asssignment4_Data.xlsx'
train_data = pd.read_excel(file_path, sheet_name='Train')
test_data = pd.read_excel(file_path, sheet_name='Test')

X_train = train_data.drop(columns=['Construction type'])
y_train = train_data['Construction type']
X_test = test_data.drop(columns=['Construction type'])
y_test = test_data['Construction type']

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

train_accuracy = accuracy_score(y_train, clf.predict(X_train))
test_accuracy = accuracy_score(y_test, clf.predict(X_test))

print(f"1 a. Accuracy on the training set: {train_accuracy:.2f}")
print(f" b. Accuracy on the test set: {test_accuracy:.2f}")
print(f"It is clearly overfitting the training data \n")

# Part 2:
depth_accuracies = []
for max_depth in range(1, 11):
    clf = DecisionTreeClassifier(max_depth=max_depth, random_state=42)
    clf.fit(X_train, y_train)
    test_acc = accuracy_score(y_test, clf.predict(X_test))
    depth_accuracies.append((max_depth, test_acc))
    print(f"Depth: {max_depth}, Test Accuracy: {test_acc:.2f}")

best_depth, best_accuracy = max(depth_accuracies, key=lambda x: x[1])
print(f"Best depth: {best_depth} with Test Accuracy: {best_accuracy:.2f}")

# Part 3:
print("""
3.
Restricting the depth of the decision tree prevents overfitting by limiting
the complexity of the model. A very deep tree will likely memorize the training
data, leading to high accuracy on the training set but poor generalization to
the test set. In this example, a depth of 2 is best balnce of complexity and simplicity
""")

# Part 4:
X_train = train_data.drop(columns=['Construction type', 'House ID'])
y_train = train_data['Construction type']
X_test = test_data.drop(columns=['Construction type', 'House ID'])
y_test = test_data['Construction type']

custom_test_point = pd.DataFrame([{
    "Local Price": 9.0384,
    "Bathrooms": 1,
    "Land Area": 7.8,
    "Living area": 1.5,
    "# Garages": 1.5,
    "# Rooms": 7,
    "# Bedrooms": 3,
    "Age of home": 23,
}])

clf = DecisionTreeClassifier(max_depth=best_depth, random_state=42)
clf.fit(X_train, y_train)

custom_prediction = clf.predict(custom_test_point)
print(f"4. Predicted class for the custom test point: {custom_prediction[0]}")
# Out:
# 1 a. Accuracy on the training set: 1.00
#  b. Accuracy on the test set: 0.40
# It is clearly overfitting the training data
#
# Depth: 1, Test Accuracy: 0.40
# Depth: 2, Test Accuracy: 0.60
# Depth: 3, Test Accuracy: 0.40
# Depth: 4, Test Accuracy: 0.40
# Depth: 5, Test Accuracy: 0.40
# Depth: 6, Test Accuracy: 0.40
# Depth: 7, Test Accuracy: 0.40
# Depth: 8, Test Accuracy: 0.40
# Depth: 9, Test Accuracy: 0.40
# Depth: 10, Test Accuracy: 0.40
# Best depth: 2 with Test Accuracy: 0.60
#
# 3.
# Restricting the depth of the decision tree prevents overfitting by limiting
# the complexity of the model. A very deep tree will likely memorize the training
# data, leading to high accuracy on the training set but poor generalization to
# the test set. In this example, a depth of 2 is best balnce of complexity and simplicity
#
# 4. Predicted class for the custom test point: Apartment
